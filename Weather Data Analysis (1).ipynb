# %% [markdown]
# # Weather Data Analysis

# %% [markdown]
# - IN THIS POJECT WE WILL USE FOLLOWING COMMANDS/OPERATIONS TO ANALYZE THE WEATHER'S DATA :-

# %% [markdown]
# ### Pandas

# %% [markdown]
# - Pandas :- Pandas is a library used to work with Data-Set.
# - Pandas has Functions for Analyzing,Cleaning,Exploring & Manipulating data.

# %%
import pandas as pd

# %% [markdown]
# ### NumPy

# %% [markdown]
# - NumPy :- NumPy library is used to perform Mathematical Operation on Arrays.

# %%
import numpy as np

# %% [markdown]
# ### Importing the DataSet/DataFrame

# %% [markdown]
# - Syntax to Load or import the DataSet(DataFrame)
# - d = pd.read_csv(r'csv_FilePath Or Location\csv_fileName')
# - d is a variable where we have stored Whole Data Set/frame

# %%
d = pd.read_csv(r'A:\MTECH(Data Science)\DataSet\archive\weather.csv')

# %% [markdown]
# ### NOW TO ANALYZE THE WEATHER'S DATA I AM USING FOLLOWING COMMANDS :-

# %% [markdown]
# # d

# %% [markdown]
# - This command will show whole Data-Set
# - print(d) are eqivalent command.

# %%
d
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 0           No      3.6          Yes
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [366 rows x 22 columns]

# %% [markdown]
# # d.head()

# %% [markdown]
# - This command will show the by default first 5 rows from the loaded DataSet.

# %%
d.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
# 2     39.8          Yes
# 3      2.8          Yes
# 4      0.0           No
#
# [5 rows x 22 columns]

# %% [markdown]
# # d.tail()

# %% [markdown]
# - This command will show the by default last 5 rows from the loaded DataSet.

# %%
d.tail()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [5 rows x 22 columns]

# %% [markdown]
# # d.head(8)

# %% [markdown]
# - This command will show the first N rows from the loaded DataSet.
# - d.head(7) = This command will show the first 7 rows from the loaded DataSet.
# - d.head(11) = This command will show the first 11 rows from the loaded DataSet.

# %%
d.head(8)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
# 5           44.0         SE          E          20.0  ...           57
# 6           43.0         SE        ESE          19.0  ...           47
# 7           41.0         SE          E          11.0  ...           57
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
# 5       1023.8       1021.7         7         5     10.9     14.8         No
# 6       1024.6       1022.2         4         6     12.4     17.3         No
# 7       1026.2       1024.2         6         7     12.1     15.5         No
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
# 2     39.8          Yes
# 3      2.8          Yes
# 4      0.0           No
# 5      0.2           No
# 6      0.0           No
# 7      0.0           No
#
# [8 rows x 22 columns]

# %% [markdown]
# # d.shape

# %% [markdown]
# - This command will show the Total No. of rows and Total No. of Columns of the loaded DataSet.

# %%
d.shape
# Out:
# (366, 22)

# %% [markdown]
# # d.index

# %% [markdown]
# - This command will show the Range of the loaded DataSet.

# %%
d.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %% [markdown]
# # d.columns

# %% [markdown]
# - This command will show the complete Attributes(columns) of the loaded DataSet.

# %%
d.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # d.dtypes

# %% [markdown]
# - This command will show the Data Type of each Column of the loaded DataSet.

# %%
d.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %% [markdown]
# # d['Column_Name'].unique()

# %% [markdown]
# - This command will show all the unique values of a particular column and it can be apply in only single column.

# %%
d['MinTemp'].unique()
# Out:
# array([ 8. , 14. , 13.7, 13.3,  7.6,  6.2,  6.1,  8.3,  8.8,  8.4,  9.1,
#         8.5, 10.1, 12.1, 12.4, 13.8, 11.7, 15.6, 15.3, 16.4, 12.8, 12. ,
#        15.4, 12.9, 15.1, 13.6, 11.6, 16.6, 14.5, 16.3, 17.2, 16.5, 15. ,
#        14.9, 11.8,  9.6,  8.9, 15.5, 10.8,  7.5, 12.6, 14.8, 19.9,  9.2,
#        11.3,  9.8, 14.3, 14.4, 15.9, 16.7, 17.5, 14.7, 20.9, 17. , 16. ,
#        17.9, 15.2, 10. ,  9.9, 10.3, 12.7, 13.2, 18. , 17.6, 17.1, 18.2,
#        16.8, 10.4,  8.6, 11.2, 11.4, 11.5, 13. ,  7.7,  4.4,  7.4,  9.5,
#        12.5, 13.9, 12.3, 13.1,  7.1,  4.2,  3.5,  5.3,  7. ,  0.4,  3.2,
#         5.9,  8.1,  6.9,  5.6,  7.2,  5.4,  6.3,  7.9,  2.4,  2.5,  5. ,
#         3.8,  4.3, -2.1, -1.8,  2.1,  0.5, -0.9, -0.2,  0.1,  1.5,  9.4,
#         1.3,  2.2, -0.4,  4.5, -2.7,  0.3,  1.2, -0.3,  4.7,  4.9,  1.4,
#        -0.1,  0.6,  4.6, 10.6,  7.8, 10.2,  7.3,  8.7,  1. ,  6.4,  4. ,
#         0.9,  0.8, -1.5,  6.6, -1.6, -3.1, -0.6,  3. ,  2.9, -1.3,  1.8,
#        -2.6,  2.7, -1.7, -1.1,  2.3, -2.2, -3.5, -1. , -2. , -2.3, -2.8,
#        -1.9,  4.8,  3.1, -2.9,  3.7, -3.4, -5.3,  0. , -3.7, -3.3,  4.1,
#         5.8,  0.2, -2.5, -0.5,  9. ,  3.9,  0.7,  1.1,  5.1,  6.5,  8.2,
#         6.7, 11.9,  3.4,  3.3])

# %% [markdown]
# # d.nunique()

# %% [markdown]
# - This command will show total no. of in unique values in each column and it can be apply in single column as well as on whole DataFrame.
# - d.nunique() Apply in whole DataFrame

# %%
d.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %% [markdown]
# # d.nunique() Apply in Single DataFrame

# %% [markdown]
# - It will show Total No. of Unique values that are present in particular column(Attribute).

# %%
d['MinTemp'].nunique()
# Out:
# 180

# %% [markdown]
# # d.value_counts

# %% [markdown]
# - This command will show all the unique values with their count(Times or frequency).
# - It can be apply in only single column.

# %%
d['MinTemp'].value_counts()
# Out:
# 0.5     6
# 4.4     6
# 15.1    5
# 3.2     5
# 2.3     5
#        ..
# 13.9    1
# 9.5     1
# 7.7     1
# 11.4    1
# 3.3     1
# Name: MinTemp, Length: 180, dtype: int64

# %%
d['RainTomorrow'].value_counts() # Show frequency
# Out:
# No     300
# Yes     66
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# # d.info()

# %% [markdown]
# - This command will provide us basic information about the DataFrame.

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
#  17  Temp9am        366 non-null    float64
#  18  Temp3pm        366 non-null    float64
#  19  RainToday      366 non-null    object
#  20  RISK_MM        366 non-null    float64
#  21  RainTomorrow   366 non-null    object
# dtypes: float64(12), int64(5), object(5)
# memory usage: 63.0+ KB

# %% [markdown]
# # d.count

# %% [markdown]
# - This command will show total no. of Non-NULL values in each column and it can be apply in single column as well as on whole DataFrame.
# - Apply in whole DataFrame

# %%
d.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %% [markdown]
# # d.notnull().sum()

# %% [markdown]
# - This command is used to check all rows amd column are filled or not in our loaded dataframe.

# %%
d.notnull().sum()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %% [markdown]
# # d.isnull().sum()

# %% [markdown]
# - This command is used to check NULL values present or not in our dataframe.
# - isnull command is used to check for null values.

# %%
pd.isnull(d).sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %% [markdown]
# ### In this Data_Frame has NULL values so first of all we have to clean it and then we will apply any kind of operations.

# %% [markdown]
# - In above cell we have got null values in following columns :-

# %% [raw]
#  Sunshine          3
#  WindGustDir       3
#  WindGustSpeed     2
#  WindDir9am       31
#  WindDir3pm        1
#  WindSpeed9am      7

# %% [markdown]
# - So we have to remove null values by using drop command.

# %%
# drop null values
d.dropna(inplace=True)

# %% [markdown]
# # After removing null values.

# %%
pd.isnull(d).sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# # Operation - 1

# %% [markdown]
# Rename Column

# %%
# Syntax
# d.rename('columns={'Old_Name_Of_Column':'New_Name_Of_Column'})
# Rename Temporary
d.rename(columns={'WindGustDir':'WindGustDirection'})
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 0        8.0     24.3       0.0          3.4       6.3                NW
# 1       14.0     26.9       3.6          4.4       9.7               ENE
# 2       13.7     23.4       3.6          5.8       3.3                NW
# 3       13.3     15.5      39.8          7.2       9.1                NW
# 4        7.6     16.1       2.8          5.6      10.6               SSE
# ..       ...      ...       ...          ...       ...               ...
# 361      9.0     30.7       0.0          7.6      12.1               NNW
# 362      7.1     28.4       0.0         11.6      12.7                 N
# 363     12.5     19.9       0.0          8.4       5.3               ESE
# 364     12.5     26.9       0.0          5.0       7.1                NW
# 365     12.3     30.2       0.0          6.0      12.6                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 0           No      3.6          Yes
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [328 rows x 22 columns]

# %%
# Above Command Rename Temporary
d.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
# To Rename Permanently
# Syntax
# d.rename('columns={Old_Name_Of_Column':'New_Name_Of_Column'},inplace=True)
d.rename(columns={'WindGustDir':'WindGustDirection'},inplace=True) # Rename Permanently

# %%
# see again it is changed or not?
d.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 0      8.0     24.3       0.0          3.4       6.3                NW
# 1     14.0     26.9       3.6          4.4       9.7               ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %% [markdown]
# # Operation - 2

# %% [markdown]
# Calculation of Mean

# %%
# Syntax
# d.Column_name.mean()
d.MinTemp.mean()
# Out:
# 7.7429878048780525

# %%
d.MaxTemp.mean()
# Out:
# 20.897560975609757

# %%
d.mean()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14252\1214089992.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.mean()
# MinTemp             7.742988
# MaxTemp            20.897561
# Rainfall            1.440854
# Evaporation         4.702439
# Sunshine            8.014939
# WindGustSpeed      40.396341
# WindSpeed9am       10.414634
# WindSpeed3pm       18.185976
# Humidity9am        71.100610
# Humidity3pm        44.003049
# Pressure9am      1019.350000
# Pressure3pm      1016.530793
# Cloud9am            3.905488
# Cloud3pm            4.000000
# Temp9am            12.815549
# Temp3pm            19.556402
# RISK_MM             1.422561
# dtype: float64

# %%
d.groupby('MinTemp').mean()
# Out:
#          MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# MinTemp
# -5.3       13.10       0.0          2.2      7.90           33.0
# -3.7       14.55       0.0          3.0     10.65           32.5
# -3.5        9.40       0.2          2.0      6.20           38.0
# -3.4       12.50       0.0          3.0      6.80           48.0
# -3.1       12.00       0.0          1.8      3.90           35.0
# ...          ...       ...          ...       ...            ...
#  17.9      33.55       0.0         10.4     10.10           52.5
#  18.0      34.90       0.0          9.2      9.90           69.0
#  18.2      22.60       1.8          8.0      0.00           33.0
#  19.9      22.00      11.0          4.4      5.90           76.0
#  20.9      35.70       0.0         13.8      6.90           50.0
#
#          WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# MinTemp
# -5.3              4.0          20.0         94.0         47.0      1029.60
# -3.7              5.5          16.5         58.5         26.5      1028.40
# -3.5             18.0          17.5         84.0         58.0      1024.15
# -3.4              7.0          30.0         89.0         30.0      1025.20
# -3.1              4.0          13.0         80.0         52.0      1030.50
# ...               ...           ...          ...          ...          ...
#  17.9            10.5          15.5         65.0         42.0      1012.95
#  18.0             6.0          13.0         68.0         29.0      1018.00
#  18.2             7.0          13.0         92.0         76.0      1014.40
#  19.9            41.0          30.0         92.0         62.0       996.50
#  20.9             4.0          17.0         61.0         28.0      1007.60
#
#          Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RISK_MM
# MinTemp
# -5.3         1025.60       6.0       6.0     0.10     12.2      0.0
# -3.7         1024.45       0.0       0.0     5.35     13.7      0.0
# -3.5         1021.85       4.5       5.5     3.45      7.6      0.2
# -3.4         1021.80       6.0       7.0     1.40     11.2      0.0
# -3.1         1030.00       1.0       6.0     5.90     10.2      0.0
# ...              ...       ...       ...      ...      ...      ...
#  17.9        1010.35       3.5       4.0    22.15     27.9      2.4
#  18.0        1013.70       1.0       6.0    22.20     33.1      5.2
#  18.2        1011.50       8.0       8.0    18.50     22.1      9.0
#  19.9         996.80       8.0       3.0    20.60     19.6     17.4
#  20.9        1003.00       7.0       2.0    23.60     34.0      2.0
#
# [170 rows x 16 columns]

# %% [markdown]
# # Operation - 3

# %% [markdown]
# Calculation of Standard Deviation

# %%
# Syntax
# d.Column_name.std()
d.MinTemp.std()
# Out:
# 5.945199248454697

# %%
d.MaxTemp.std()
# Out:
# 6.7073099127283315

# %%
d.std()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14252\4080983771.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.std()
# MinTemp           5.945199
# MaxTemp           6.707310
# Rainfall          4.289427
# Evaporation       2.681183
# Sunshine          3.506646
# WindGustSpeed    13.132176
# WindSpeed9am      7.811544
# WindSpeed3pm      8.926759
# Humidity9am      12.983367
# Humidity3pm      16.605975
# Pressure9am       6.715244
# Pressure3pm       6.469774
# Cloud9am          2.974957
# Cloud3pm          2.652101
# Temp9am           5.542521
# Temp3pm           6.644311
# RISK_MM           4.234023
# dtype: float64

# %% [markdown]
# # Operation - 4

# %% [markdown]
# Calculation of Variance

# %%
# Syntax
# d.Column_name.var()
d.MinTemp.var()
# Out:
# 35.3453941038263

# %%
d.MaxTemp.var()
# Out:
# 44.98800626538374

# %%
d.var()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14252\3511739826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.var()
# MinTemp           35.345394
# MaxTemp           44.988006
# Rainfall          18.399182
# Evaporation        7.188740
# Sunshine          12.296565
# WindGustSpeed    172.454054
# WindSpeed9am      61.020213
# WindSpeed3pm      79.687020
# Humidity9am      168.567828
# Humidity3pm      275.758400
# Pressure9am       45.094495
# Pressure3pm       41.857979
# Cloud9am           8.850367
# Cloud3pm           7.033639
# Temp9am           30.719543
# Temp3pm           44.146870
# RISK_MM           17.926951
# dtype: float64

# %% [markdown]
# # Operation - 5

# %% [markdown]
# Calculation of Median

# %%
# Syntax
# d.Column_name.median()
d.MinTemp.median()
# Out:
# 7.9

# %%
d.MaxTemp.median()
# Out:
# 20.4

# %%
d.median()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14252\3286961719.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.median()
# MinTemp             7.90
# MaxTemp            20.40
# Rainfall            0.00
# Evaporation         4.40
# Sunshine            8.75
# WindGustSpeed      39.00
# WindSpeed9am        7.00
# WindSpeed3pm       17.00
# Humidity9am        71.00
# Humidity3pm        42.50
# Pressure9am      1019.75
# Pressure3pm      1016.90
# Cloud9am            4.00
# Cloud3pm            4.00
# Temp9am            13.50
# Temp3pm            18.85
# RISK_MM             0.00
# dtype: float64

# %% [markdown]
# # Operation - 6

# %% [markdown]
# Calculation of Mode

# %%
# Syntax
# d.Column_name.mode()
d.MinTemp.mode()
# Out:
# 0    4.4
# Name: MinTemp, dtype: float64

# %%
d.mode()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 0      4.4     11.6       0.0          2.8       0.0                NW
# 1      NaN     14.7       NaN          NaN       8.4               NaN
# 2      NaN     14.8       NaN          NaN       NaN               NaN
# 3      NaN     18.9       NaN          NaN       NaN               NaN
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           39.0         SE         NW           6.0  ...         34.0
# 1            NaN        NaN        NaN           NaN  ...          NaN
# 2            NaN        NaN        NaN           NaN  ...          NaN
# 3            NaN        NaN        NaN           NaN  ...          NaN
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1023.2       1019.3       1.0       1.0     14.0     11.1         No
# 1       1025.7          NaN       NaN       NaN      NaN      NaN        NaN
# 2          NaN          NaN       NaN       NaN      NaN      NaN        NaN
# 3          NaN          NaN       NaN       NaN      NaN      NaN        NaN
#
#    RISK_MM RainTomorrow
# 0      0.0           No
# 1      NaN          NaN
# 2      NaN          NaN
# 3      NaN          NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# # Operation - 7

# %% [markdown]
# Calculation of Kurtosis

# %%
# Syntax
# d.Column_name.kurt()
# for single attribute
d.MinTemp.kurt()
# Out:
# -1.0678732874693733

# %%
# For complete attributers
d.kurt()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14252\1413420561.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.kurt()
# MinTemp          -1.067873
# MaxTemp          -0.751754
# Rainfall         27.611392
# Evaporation      -0.216054
# Sunshine         -0.266922
# WindGustSpeed     1.594871
# WindSpeed9am      1.535232
# WindSpeed3pm      0.265588
# Humidity9am      -0.145622
# Humidity3pm      -0.118062
# Pressure9am      -0.088998
# Pressure3pm       0.000914
# Cloud9am         -1.719883
# Cloud3pm         -1.621962
# Temp9am          -0.881008
# Temp3pm          -0.670370
# RISK_MM          28.557778
# dtype: float64

# %% [markdown]
# # Operation - 8

# %% [markdown]
# Calculation of Skewness

# %%
# Syntax
# d.Column_name.skew()
d.MinTemp.skew()
# Out:
# -0.07365803681446856

# %%
# For complete attributers
d.skew()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14252\3048699516.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.skew()
# MinTemp         -0.073658
# MaxTemp          0.297350
# Rainfall         4.679845
# Evaporation      0.598352
# Sunshine        -0.737128
# WindGustSpeed    0.891562
# WindSpeed9am     1.430616
# WindSpeed3pm     0.646106
# Humidity9am     -0.091999
# Humidity3pm      0.539732
# Pressure9am     -0.331647
# Pressure3pm     -0.267506
# Cloud9am         0.078980
# Cloud3pm         0.080163
# Temp9am         -0.094301
# Temp3pm          0.263944
# RISK_MM          4.723079
# dtype: float64

# %% [markdown]
# # Operation - 9

# %% [markdown]
# Calculation of Correlation

# %%
# Syntax
# d.corr()
d.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.745911  0.197339     0.634720  0.007730
# MaxTemp        0.745911  1.000000 -0.077263     0.673162  0.444863
# Rainfall       0.197339 -0.077263  1.000000    -0.011767 -0.158062
# Evaporation    0.634720  0.673162 -0.011767     1.000000  0.310124
# Sunshine       0.007730  0.444863 -0.158062     0.310124  1.000000
# WindGustSpeed  0.190596  0.070911  0.099442     0.258050  0.084768
# WindSpeed9am   0.058319 -0.296485  0.238705     0.006259 -0.103841
# WindSpeed3pm  -0.106321 -0.219886  0.058151     0.019594  0.046140
# Humidity9am   -0.160781 -0.325106  0.146321    -0.492218 -0.501596
# Humidity3pm   -0.013897 -0.520412  0.287244    -0.374532 -0.760267
# Pressure9am   -0.502352 -0.268054 -0.348731    -0.363936  0.025630
# Pressure3pm   -0.503255 -0.367040 -0.263710    -0.380702 -0.024120
# Cloud9am       0.211640 -0.187416  0.172610    -0.114261 -0.697603
# Cloud3pm       0.125914 -0.144976  0.134894    -0.111387 -0.657198
# Temp9am        0.910805  0.869609  0.071893     0.688749  0.199659
# Temp3pm        0.716051  0.988925 -0.089740     0.655896  0.463721
# RISK_MM        0.251519  0.058638  0.101909     0.099727 -0.357231
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.190596      0.058319     -0.106321    -0.160781
# MaxTemp             0.070911     -0.296485     -0.219886    -0.325106
# Rainfall            0.099442      0.238705      0.058151     0.146321
# Evaporation         0.258050      0.006259      0.019594    -0.492218
# Sunshine            0.084768     -0.103841      0.046140    -0.501596
# WindGustSpeed       1.000000      0.540717      0.687071    -0.338276
# WindSpeed9am        0.540717      1.000000      0.495946    -0.222337
# WindSpeed3pm        0.687071      0.495946      1.000000    -0.260960
# Humidity9am        -0.338276     -0.222337     -0.260960     1.000000
# Humidity3pm        -0.043254      0.202122      0.015860     0.526695
# Pressure9am        -0.524737     -0.344290     -0.344889     0.102250
# Pressure3pm        -0.510826     -0.233682     -0.318008     0.109549
# Cloud9am           -0.018216      0.117625     -0.033882     0.417496
# Cloud3pm            0.042849     -0.012990      0.011625     0.289618
# Temp9am             0.229164     -0.017843     -0.057454    -0.395647
# Temp3pm             0.036039     -0.315906     -0.239119    -0.321299
# RISK_MM             0.269151      0.053529      0.012931     0.157148
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp          -0.013897    -0.502352    -0.503255  0.211640  0.125914
# MaxTemp          -0.520412    -0.268054    -0.367040 -0.187416 -0.144976
# Rainfall          0.287244    -0.348731    -0.263710  0.172610  0.134894
# Evaporation      -0.374532    -0.363936    -0.380702 -0.114261 -0.111387
# Sunshine         -0.760267     0.025630    -0.024120 -0.697603 -0.657198
# WindGustSpeed    -0.043254    -0.524737    -0.510826 -0.018216  0.042849
# WindSpeed9am      0.202122    -0.344290    -0.233682  0.117625 -0.012990
# WindSpeed3pm      0.015860    -0.344889    -0.318008 -0.033882  0.011625
# Humidity9am       0.526695     0.102250     0.109549  0.417496  0.289618
# Humidity3pm       1.000000    -0.136289    -0.047607  0.565174  0.530715
# Pressure9am      -0.136289     1.000000     0.966744 -0.168316 -0.146196
# Pressure3pm      -0.047607     0.966744     1.000000 -0.132247 -0.146235
# Cloud9am          0.565174    -0.168316    -0.132247  1.000000  0.528296
# Cloud3pm          0.530715    -0.146196    -0.146235  0.528296  1.000000
# Temp9am          -0.230820    -0.453669    -0.496853  0.010012  0.044542
# Temp3pm          -0.569348    -0.229817    -0.332099 -0.213509 -0.181667
# RISK_MM           0.323494    -0.314815    -0.336461  0.268979  0.311882
#
#                 Temp9am   Temp3pm   RISK_MM
# MinTemp        0.910805  0.716051  0.251519
# MaxTemp        0.869609  0.988925  0.058638
# Rainfall       0.071893 -0.089740  0.101909
# Evaporation    0.688749  0.655896  0.099727
# Sunshine       0.199659  0.463721 -0.357231
# WindGustSpeed  0.229164  0.036039  0.269151
# WindSpeed9am  -0.017843 -0.315906  0.053529
# WindSpeed3pm  -0.057454 -0.239119  0.012931
# Humidity9am   -0.395647 -0.321299  0.157148
# Humidity3pm   -0.230820 -0.569348  0.323494
# Pressure9am   -0.453669 -0.229817 -0.314815
# Pressure3pm   -0.496853 -0.332099 -0.336461
# Cloud9am       0.010012 -0.213509  0.268979
# Cloud3pm       0.044542 -0.181667  0.311882
# Temp9am        1.000000  0.843509  0.201508
# Temp3pm        0.843509  1.000000  0.028888
# RISK_MM        0.201508  0.028888  1.000000

# %% [markdown]
# # Operation - 10

# %% [markdown]
# FILTER

# %% [markdown]
# We are filtring the records where the attribute RainTomorrow has only Yes.

# %%
# Syntax
# d[d['Column_name']=='value']

d[d['RainTomorrow']=='Yes']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 0        8.0     24.3       0.0          3.4       6.3                NW
# 1       14.0     26.9       3.6          4.4       9.7               ENE
# 2       13.7     23.4       3.6          5.8       3.3                NW
# 3       13.3     15.5      39.8          7.2       9.1                NW
# 8        8.8     19.5       0.0          4.0       4.1                 S
# 16      13.8     31.2       0.0          7.2       8.4               ESE
# 21      16.4     19.4       0.4          9.2       0.0                 E
# 29      13.6     24.1       0.4          2.6       0.5               NNW
# 30      15.1     20.4      22.6          2.4       0.2               SSE
# 32      16.6     24.2       0.2          6.6       4.7                NW
# 36      17.2     25.8       0.0          4.2       8.8                SW
# 44      10.1     29.9       0.0          6.8       8.8                 E
# 45      15.5     21.1       5.4          6.4       0.9                 S
# 48      12.8     21.0       0.0          6.4       0.8                NE
# 49      12.6     23.1       3.4          1.6       2.3               NNW
# 50      14.8     29.5       6.4          1.8       8.1                 N
# 51      19.9     22.0      11.0          4.4       5.9               NNW
# 53      12.4     24.4       0.0          6.2      12.1                NW
# 56      14.3     26.7       0.0          7.2       7.1               NNW
# 72      20.9     35.7       0.0         13.8       6.9                SW
# 76      17.9     33.2       0.0         10.4       8.4                 N
# 78      15.1     20.4       0.0          9.6       0.1               ESE
# 79      15.3     19.6      18.8          5.0       0.0                NE
# 90      18.0     34.9       0.0          9.2       9.9                NW
# 91      17.6     27.8       5.2         10.2       3.6               ESE
# 94      17.1     29.6       0.0          5.8       9.2                 E
# 95      18.2     22.6       1.8          8.0       0.0               ENE
# 98      14.5     24.2       0.0          6.8       5.9               SSW
# 102      8.9     26.0       0.0          5.0      10.7                NE
# 103     14.5     24.2       4.4          6.6       5.9                 W
# 111     12.0     28.9       0.0          7.2       8.2               ESE
# 112     16.3     24.8       1.8          7.8       3.8                 S
# 119     14.8     17.3       0.0          7.6       0.8               SSE
# 144     15.5     22.4       0.6          4.8       1.9                NW
# 145     13.1     17.4       6.4          2.8       0.0               NNW
# 153      5.3     23.3       0.0          3.6       5.6               NNW
# 163      6.1     24.1       0.0          4.6       6.1               WNW
# 164      7.1     19.8       2.0          3.2       7.7                 W
# 178      7.9     18.7       0.0          5.8       5.8                NW
# 196     -0.4     17.9       0.0          2.4       8.7                NW
# 206     -0.3     17.5       0.0          1.6       8.4                 W
# 207      4.7     18.5       3.8          2.0       5.1               ESE
# 215      9.8     14.4       0.8          0.6       0.0               ESE
# 231      4.0     15.9       0.0          0.6       2.0               NNW
# 242      0.5     15.4       0.0          2.4       6.4                 W
# 252      1.8      8.7       0.0          1.8       1.2                NW
# 260      1.3     10.6       0.0          0.8       5.6                NW
# 269     -2.3      9.7       0.0          1.4       1.9               SSE
# 274      3.0      9.7       1.0          2.6       0.7                 W
# 280     -0.6     11.1       0.0          3.0       5.0               NNW
# 303      0.5     16.3       0.0          1.8       4.1               NNW
# 304      6.1     17.2       4.0          2.2       2.4                NW
# 317      9.0     25.5       0.0          5.6      10.2                NW
# 318     13.1     19.4       9.8          8.8       6.0               NNW
# 319      8.7     19.7       1.6          5.2       8.0                NW
# 326      3.2     21.9       0.0          6.8       5.2                NW
# 337     16.8     28.9       0.0         10.0      10.8               NNW
# 338     14.4     20.7       7.6          9.4       4.9               NNW
# 340     11.2     18.0       0.0          4.8       8.4                 W
# 347      6.7     26.1       0.0          6.2       7.5               SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 8             48.0          E        ENE          19.0  ...           48
# 16            44.0        WSW          W           6.0  ...           23
# 21            26.0        ENE          E           6.0  ...           72
# 29            30.0        SSW          S           6.0  ...           49
# 30            41.0          E          S           6.0  ...           90
# 32            50.0        WNW         NW          13.0  ...           60
# 36            41.0         NW          N           6.0  ...           74
# 44            41.0         SE        WNW           2.0  ...           36
# 45            31.0        SSE         NE           6.0  ...           86
# 48            22.0         NE        ENE           7.0  ...           54
# 49            30.0          N         NW           4.0  ...           74
# 50            41.0         NW         NW           6.0  ...           48
# 51            76.0          N        WNW          41.0  ...           62
# 53            44.0        NNW        WNW           7.0  ...           43
# 56            65.0          N        NNW           7.0  ...           64
# 72            50.0          E        WNW           4.0  ...           28
# 76            59.0          N        NNE          15.0  ...           62
# 78            39.0        ESE        ESE          17.0  ...           55
# 79            33.0        SSE        NNE           9.0  ...           88
# 90            69.0          N          W           6.0  ...           29
# 91            39.0          N        NNW          13.0  ...           49
# 94            48.0         SE        ESE           9.0  ...           38
# 95            33.0        SSE        ENE           7.0  ...           76
# 98            61.0          N        NNW          11.0  ...           76
# 102           31.0         SE         NE           7.0  ...           34
# 103           48.0        NNW        WNW           9.0  ...           60
# 111           39.0        SSE        WNW           2.0  ...           31
# 112           50.0        NNW          N           4.0  ...           56
# 119           48.0          S         SE          13.0  ...           78
# 144           28.0        SSE        WNW           6.0  ...           68
# 145           43.0          N          N          11.0  ...           93
# 153           83.0        SSW         NW           2.0  ...           26
# 163           35.0        SSW        WNW           6.0  ...           32
# 164           39.0        SSE         NW          13.0  ...           56
# 178           59.0        NNW         NW          26.0  ...           51
# 196           33.0        NNE         NW           2.0  ...           40
# 206           39.0         SE        NNW           6.0  ...           48
# 207           22.0        NNW          W           6.0  ...           50
# 215           20.0          S        ESE           9.0  ...           86
# 231           17.0         SE        SSE           6.0  ...           63
# 242           70.0         NW        NNW          22.0  ...           68
# 252           65.0         NW         NW          31.0  ...           85
# 260           46.0        NNW        WNW          24.0  ...           73
# 269           28.0        SSE        WSW           6.0  ...           66
# 274           65.0         NW         NW          19.0  ...           82
# 280           41.0         SE          N           7.0  ...           78
# 303           39.0        SSW        WSW           4.0  ...           45
# 304           59.0         NW        WNW          24.0  ...           85
# 317           50.0          N         NW          20.0  ...           31
# 318           67.0          N         NW          39.0  ...           43
# 319           98.0         NW        NNW          31.0  ...           33
# 326           80.0        SSE         NW           2.0  ...           50
# 337           70.0         NW         NW          31.0  ...           22
# 338           33.0        NNW        NNW          20.0  ...           65
# 340           65.0          N          W          24.0  ...           40
# 347           70.0         NE        NNW           6.0  ...           47
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 8         1026.1       1022.7         7         7     14.1     18.9
# 16        1014.4       1009.8         7         6     20.2     29.8
# 21        1010.7       1008.9         8         8     16.5     18.3
# 29        1017.2       1013.3         8         7     17.3     23.2
# 30        1015.0       1014.1         8         8     17.0     16.3
# 32        1007.9       1004.6         7         7     20.5     19.9
# 36        1014.5       1011.5         6         7     21.5     22.6
# 44        1012.6       1010.2         1         8     17.4     29.1
# 45        1010.1       1008.6         8         8     16.6     20.0
# 48        1018.0       1015.6         8         8     16.1     20.0
# 49        1015.8       1014.1         8         7     15.3     20.4
# 50        1012.9       1008.3         2         7     21.0     28.2
# 51         996.5        996.8         8         3     20.6     19.6
# 53        1012.8       1009.7         6         4     15.0     22.5
# 56        1017.3       1014.3         7         7     19.8     19.0
# 72        1007.6       1003.0         7         2     23.6     34.0
# 76        1008.5       1006.1         6         7     24.5     23.5
# 78        1017.5       1015.8         8         8     17.8     19.4
# 79        1008.7       1006.0         8         8     18.0     18.6
# 90        1018.0       1013.7         1         6     22.2     33.1
# 91        1014.6       1012.8         7         8     21.4     26.3
# 94        1016.7       1012.8         6         7     21.7     29.1
# 95        1014.4       1011.5         8         8     18.5     22.1
# 98         999.4        998.9         7         7     17.9     20.3
# 102       1016.1       1011.7         1         5     14.6     24.2
# 103       1010.8       1006.8         8         5     15.8     22.6
# 111       1012.2       1009.1         2         7     17.4     28.6
# 112       1011.8       1008.4         7         7     17.5     24.0
# 119       1010.0       1009.9         7         7     15.7     15.3
# 144       1018.7       1015.4         8         7     17.1     21.1
# 145       1010.2       1006.5         8         8     16.4     16.6
# 153       1018.0       1010.5         1         8      9.5     22.5
# 163       1019.2       1015.8         7         3     11.5     23.7
# 164       1018.4       1013.8         5         2     10.7     19.1
# 178       1003.2        997.7         6         6     14.4     16.6
# 196       1023.5       1018.7         1         2      6.8     17.7
# 206       1025.5       1021.8         1         5      6.2     17.2
# 207       1026.6       1023.1         7         4      7.0     17.9
# 215       1028.5       1027.2         8         8     12.1     13.6
# 231       1022.5       1019.7         8         7      8.4     14.8
# 242       1017.2       1010.2         1         7      9.7     12.9
# 252       1014.6       1010.5         7         7      6.0      6.9
# 260       1010.8       1009.4         3         5      7.7      8.2
# 269       1013.8       1010.0         7         7      1.0      7.8
# 274       1005.1       1001.3         8         7      9.6      8.6
# 280       1018.4       1015.9         7         7      3.8      5.7
# 303       1023.7       1017.5         7         8      6.2     15.4
# 304       1011.2       1010.4         7         7     13.5     12.6
# 317       1015.3       1011.4         3         1     17.5     25.1
# 318       1007.3       1006.0         7         1     16.7     18.2
# 319       1009.1       1001.5         3         6     15.6     18.5
# 326       1012.1       1006.5         1         8     15.9     21.0
# 337       1016.3       1011.8         1         1     22.5     28.4
# 338       1015.5       1013.2         8         4     14.5     19.3
# 340       1009.5       1005.3         5         4     12.8     16.2
# 347       1020.9       1016.0         4         7     16.3     23.2
#
#      RainToday  RISK_MM RainTomorrow
# 0           No      3.6          Yes
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 8           No     16.2          Yes
# 16          No      1.2          Yes
# 21          No     25.8          Yes
# 29          No     22.6          Yes
# 30         Yes      4.2          Yes
# 32          No      6.6          Yes
# 36          No      4.0          Yes
# 44          No      5.4          Yes
# 45         Yes      1.4          Yes
# 48          No      3.4          Yes
# 49         Yes      6.4          Yes
# 50         Yes     11.0          Yes
# 51         Yes     17.4          Yes
# 53          No      3.4          Yes
# 56          No     14.4          Yes
# 72          No      2.0          Yes
# 76          No      4.8          Yes
# 78          No     18.8          Yes
# 79         Yes     12.2          Yes
# 90          No      5.2          Yes
# 91         Yes      2.2          Yes
# 94          No      1.8          Yes
# 95         Yes      9.0          Yes
# 98          No     16.2          Yes
# 102         No      4.4          Yes
# 103        Yes     11.0          Yes
# 111         No      1.8          Yes
# 112        Yes      6.6          Yes
# 119         No     10.4          Yes
# 144         No      6.4          Yes
# 145        Yes     19.8          Yes
# 153         No      2.6          Yes
# 163         No      2.0          Yes
# 164        Yes      5.2          Yes
# 178         No      7.2          Yes
# 196         No      1.8          Yes
# 206         No      3.8          Yes
# 207        Yes      5.2          Yes
# 215         No      3.8          Yes
# 231         No      4.8          Yes
# 242         No      2.0          Yes
# 252         No      1.6          Yes
# 260         No      1.2          Yes
# 269         No      1.4          Yes
# 274         No      6.6          Yes
# 280         No      1.2          Yes
# 303         No      4.0          Yes
# 304        Yes      7.4          Yes
# 317         No      9.8          Yes
# 318        Yes      1.6          Yes
# 319        Yes      3.4          Yes
# 326         No     17.4          Yes
# 337         No      7.6          Yes
# 338        Yes      3.0          Yes
# 340         No      8.2          Yes
# 347         No     13.2          Yes
#
# [60 rows x 22 columns]

# %% [markdown]
# # Operation - 11

# %% [markdown]
# FILTER

# %% [markdown]
# We are filtring the records where the attribute RainTomorrow has only No.

# %%
d[d['RainTomorrow']=='No']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 4        7.6     16.1       2.8          5.6      10.6               SSE
# 5        6.2     16.9       0.0          5.8       8.2                SE
# 6        6.1     18.2       0.2          4.2       8.4                SE
# 7        8.3     17.0       0.0          5.6       4.6                 E
# 9        8.4     22.8      16.2          5.4       7.7                 E
# ..       ...      ...       ...          ...       ...               ...
# 361      9.0     30.7       0.0          7.6      12.1               NNW
# 362      7.1     28.4       0.0         11.6      12.7                 N
# 363     12.5     19.9       0.0          8.4       5.3               ESE
# 364     12.5     26.9       0.0          5.0       7.1                NW
# 365     12.3     30.2       0.0          6.0      12.6                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 4             50.0        SSE        ESE          20.0  ...           49
# 5             44.0         SE          E          20.0  ...           57
# 6             43.0         SE        ESE          19.0  ...           47
# 7             41.0         SE          E          11.0  ...           57
# 9             31.0          S        ESE           7.0  ...           32
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 4         1018.3       1018.5         7         7     11.1     15.4
# 5         1023.8       1021.7         7         5     10.9     14.8
# 6         1024.6       1022.2         4         6     12.4     17.3
# 7         1026.2       1024.2         6         7     12.1     15.5
# 9         1024.1       1020.7         7         1     13.3     21.7
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 4          Yes      0.0           No
# 5           No      0.2           No
# 6           No      0.0           No
# 7           No      0.0           No
# 9          Yes      0.0           No
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [268 rows x 22 columns]

# %% [markdown]
# # Operation - 12

# %% [markdown]
# Calculation of Minimum Value

# %%
# This command will give us minimum value from each column.
d.min()
# Out:
# MinTemp               -5.3
# MaxTemp                7.6
# Rainfall               0.0
# Evaporation            0.2
# Sunshine               0.0
# WindGustDirection        E
# WindGustSpeed         13.0
# WindDir9am               E
# WindDir3pm               E
# WindSpeed9am           2.0
# WindSpeed3pm             4
# Humidity9am             36
# Humidity3pm             13
# Pressure9am          996.5
# Pressure3pm          996.8
# Cloud9am                 0
# Cloud3pm                 0
# Temp9am                0.1
# Temp3pm                5.1
# RainToday               No
# RISK_MM                0.0
# RainTomorrow            No
# dtype: object

# %%
# For Particular column
d['RISK_MM'].min()
# Out:
# 0.0

# %%
d.groupby('MinTemp').min()
# Out:
#          MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# MinTemp
# -5.3        13.1       0.0          2.2       7.9                NW
# -3.7        14.4       0.0          2.6      10.4               NNW
# -3.5         7.6       0.0          1.6       4.7               ESE
# -3.4        12.5       0.0          3.0       6.8               SSE
# -3.1        12.0       0.0          1.8       3.9               ESE
# ...          ...       ...          ...       ...               ...
#  17.9       33.2       0.0         10.4       8.4               ENE
#  18.0       34.9       0.0          9.2       9.9                NW
#  18.2       22.6       1.8          8.0       0.0               ENE
#  19.9       22.0      11.0          4.4       5.9               NNW
#  20.9       35.7       0.0         13.8       6.9                SW
#
#          WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  \
# MinTemp                                                                   ...
# -5.3              33.0          N        NNW           4.0            20  ...
# -3.7              22.0          N          N           2.0            11  ...
# -3.5              26.0          N        ESE           6.0            11  ...
# -3.4              48.0        NNW        WNW           7.0            30  ...
# -3.1              35.0        SSW         NE           4.0            13  ...
# ...                ...        ...        ...           ...           ...  ...
#  17.9             46.0          N        NNE           6.0            11  ...
#  18.0             69.0          N          W           6.0            13  ...
#  18.2             33.0        SSE        ENE           7.0            13  ...
#  19.9             76.0          N        WNW          41.0            30  ...
#  20.9             50.0          E        WNW           4.0            17  ...
#
#          Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# MinTemp
# -5.3              47       1029.6       1025.6         6         6      0.1
# -3.7              25       1025.8       1020.9         0         0      5.2
# -3.5              48       1014.8       1012.6         1         5      3.3
# -3.4              30       1025.2       1021.8         6         7      1.4
# -3.1              52       1030.5       1030.0         1         6      5.9
# ...              ...          ...          ...       ...       ...      ...
#  17.9             22       1008.5       1006.1         1         1     19.8
#  18.0             29       1018.0       1013.7         1         6     22.2
#  18.2             76       1014.4       1011.5         8         8     18.5
#  19.9             62        996.5        996.8         8         3     20.6
#  20.9             28       1007.6       1003.0         7         2     23.6
#
#          Temp3pm  RainToday RISK_MM  RainTomorrow
# MinTemp
# -5.3        12.2         No     0.0            No
# -3.7        13.4         No     0.0            No
# -3.5         5.1         No     0.0            No
# -3.4        11.2         No     0.0            No
# -3.1        10.2         No     0.0            No
# ...          ...        ...     ...           ...
#  17.9       23.5         No     0.0            No
#  18.0       33.1         No     5.2           Yes
#  18.2       22.1        Yes     9.0           Yes
#  19.9       19.6        Yes    17.4           Yes
#  20.9       34.0         No     2.0           Yes
#
# [170 rows x 21 columns]

# %% [markdown]
# # d.sum()

# %%
d.sum()
# Out:
# MinTemp                                                         2539.7
# MaxTemp                                                         6854.4
# Rainfall                                                         472.6
# Evaporation                                                     1542.4
# Sunshine                                                        2628.9
# WindGustDirection    NWENENWNWSSESESEESENEWNWNWNWEESESENEWNWEESENNE...
# WindGustSpeed                                                  13250.0
# WindDir9am           SWENWNWSSESESESEESSEESWNWSSEWSWSWNNENNWNENESWS...
# WindDir3pm           NWWNNEWESEEESEEENEESENWNWNWWWWSWWNEWNNWNWESENE...
# WindSpeed9am                                                    3416.0
# WindSpeed3pm                                                      5965
# Humidity9am                                                      23321
# Humidity3pm                                                      14433
# Pressure9am                                                   334346.8
# Pressure3pm                                                   333422.1
# Cloud9am                                                          1281
# Cloud3pm                                                          1312
# Temp9am                                                         4203.5
# Temp3pm                                                         6414.5
# RainToday            NoYesYesYesYesNoNoNoNoYesNoNoNoNoNoNoNoYesNoNo...
# RISK_MM                                                          466.6
# RainTomorrow         YesYesYesYesNoNoNoNoYesNoNoNoNoNoNoNoYesNoNoNo...
# dtype: object

# %% [markdown]
# # d.describe()

# %% [markdown]
# - This command will show us count, mean, std, min, max of whole dataframe.

# %%
d.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  328.000000  328.000000  328.000000   328.000000  328.000000
# mean     7.742988   20.897561    1.440854     4.702439    8.014939
# std      5.945199    6.707310    4.289427     2.681183    3.506646
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.850000   15.500000    0.000000     2.550000    6.000000
# 50%      7.900000   20.400000    0.000000     4.400000    8.750000
# 75%     12.800000   25.800000    0.200000     6.600000   10.700000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     328.000000    328.000000    328.000000   328.000000   328.000000
# mean       40.396341     10.414634     18.185976    71.100610    44.003049
# std        13.132176      7.811544      8.926759    12.983367    16.605975
# min        13.000000      2.000000      4.000000    36.000000    13.000000
# 25%        31.000000      6.000000     11.000000    63.000000    32.000000
# 50%        39.000000      7.000000     17.000000    71.000000    42.500000
# 75%        46.000000     13.000000     24.000000    80.000000    54.000000
# max        98.000000     41.000000     52.000000    99.000000    93.000000
#
#        Pressure9am  Pressure3pm    Cloud9am    Cloud3pm     Temp9am  \
# count   328.000000   328.000000  328.000000  328.000000  328.000000
# mean   1019.350000  1016.530793    3.905488    4.000000   12.815549
# std       6.715244     6.469774    2.974957    2.652101    5.542521
# min     996.500000   996.800000    0.000000    0.000000    0.100000
# 25%    1014.800000  1012.400000    1.000000    1.000000    8.175000
# 50%    1019.750000  1016.900000    4.000000    4.000000   13.500000
# 75%    1024.300000  1021.125000    7.000000    7.000000   17.200000
# max    1035.700000  1033.200000    8.000000    8.000000   24.700000
#
#           Temp3pm     RISK_MM
# count  328.000000  328.000000
# mean    19.556402    1.422561
# std      6.644311    4.234023
# min      5.100000    0.000000
# 25%     14.500000    0.000000
# 50%     18.850000    0.000000
# 75%     24.225000    0.200000
# max     34.500000   39.800000

# %% [markdown]
# # Operation - 13

# %% [markdown]
# Calculation of Maximum Value

# %%
# This command will give us maximum value from each column.
d.max()
# Out:
# MinTemp                20.9
# MaxTemp                35.8
# Rainfall               39.8
# Evaporation            13.8
# Sunshine               13.6
# WindGustDirection       WSW
# WindGustSpeed          98.0
# WindDir9am              WSW
# WindDir3pm              WSW
# WindSpeed9am           41.0
# WindSpeed3pm             52
# Humidity9am              99
# Humidity3pm              93
# Pressure9am          1035.7
# Pressure3pm          1033.2
# Cloud9am                  8
# Cloud3pm                  8
# Temp9am                24.7
# Temp3pm                34.5
# RainToday               Yes
# RISK_MM                39.8
# RainTomorrow            Yes
# dtype: object

# %%
# For Particular column
d['RISK_MM'].max()
# Out:
# 39.8

# %%
d.groupby('MinTemp').max()
# Out:
#          MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# MinTemp
# -5.3        13.1       0.0          2.2       7.9                NW
# -3.7        14.7       0.0          3.4      10.9               SSE
# -3.5        11.2       0.4          2.4       7.7                NW
# -3.4        12.5       0.0          3.0       6.8               SSE
# -3.1        12.0       0.0          1.8       3.9               ESE
# ...          ...       ...          ...       ...               ...
#  17.9       33.9       0.0         10.4      11.8                 N
#  18.0       34.9       0.0          9.2       9.9                NW
#  18.2       22.6       1.8          8.0       0.0               ENE
#  19.9       22.0      11.0          4.4       5.9               NNW
#  20.9       35.7       0.0         13.8       6.9                SW
#
#          WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  \
# MinTemp                                                                   ...
# -5.3              33.0          N        NNW           4.0            20  ...
# -3.7              43.0         SE        NNW           9.0            22  ...
# -3.5              50.0         NW         NW          30.0            24  ...
# -3.4              48.0        NNW        WNW           7.0            30  ...
# -3.1              35.0        SSW         NE           4.0            13  ...
# ...                ...        ...        ...           ...           ...  ...
#  17.9             59.0          S          W          15.0            20  ...
#  18.0             69.0          N          W           6.0            13  ...
#  18.2             33.0        SSE        ENE           7.0            13  ...
#  19.9             76.0          N        WNW          41.0            30  ...
#  20.9             50.0          E        WNW           4.0            17  ...
#
#          Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# MinTemp
# -5.3              47       1029.6       1025.6         6         6      0.1
# -3.7              28       1031.0       1028.0         0         0      5.5
# -3.5              68       1033.5       1031.1         8         6      3.6
# -3.4              30       1025.2       1021.8         6         7      1.4
# -3.1              52       1030.5       1030.0         1         6      5.9
# ...              ...          ...          ...       ...       ...      ...
#  17.9             62       1017.4       1014.6         6         7     24.5
#  18.0             29       1018.0       1013.7         1         6     22.2
#  18.2             76       1014.4       1011.5         8         8     18.5
#  19.9             62        996.5        996.8         8         3     20.6
#  20.9             28       1007.6       1003.0         7         2     23.6
#
#          Temp3pm  RainToday RISK_MM  RainTomorrow
# MinTemp
# -5.3        12.2         No     0.0            No
# -3.7        14.0         No     0.0            No
# -3.5        10.1         No     0.4            No
# -3.4        11.2         No     0.0            No
# -3.1        10.2         No     0.0            No
# ...          ...        ...     ...           ...
#  17.9       32.3         No     4.8           Yes
#  18.0       33.1         No     5.2           Yes
#  18.2       22.1        Yes     9.0           Yes
#  19.9       19.6        Yes    17.4           Yes
#  20.9       34.0         No     2.0           Yes
#
# [170 rows x 21 columns]

# %% [markdown]
# # Operation - 14

# %% [markdown]
# str.contains

# %% [markdown]
# # Retrieved data only if RainToday is Yes

# %%
d[(d['RainToday'].str.contains('Yes'))]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 1       14.0     26.9       3.6          4.4       9.7               ENE
# 2       13.7     23.4       3.6          5.8       3.3                NW
# 3       13.3     15.5      39.8          7.2       9.1                NW
# 4        7.6     16.1       2.8          5.6      10.6               SSE
# 9        8.4     22.8      16.2          5.4       7.7                 E
# ..       ...      ...       ...          ...       ...               ...
# 320      3.9     13.2       3.4          6.6      11.0               WNW
# 327      7.8     16.2      17.4          6.4       7.9                NW
# 338     14.4     20.7       7.6          9.4       4.9               NNW
# 339     10.3     21.3       3.0          4.2       6.7               NNW
# 341      0.3     16.0       8.2          5.4      11.8                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# 9             31.0          S        ESE           7.0  ...           32
# ..             ...        ...        ...           ...  ...          ...
# 320           65.0        WNW        WNW          26.0  ...           33
# 327           50.0         NW          N          15.0  ...           44
# 338           33.0        NNW        NNW          20.0  ...           65
# 339           43.0        ENE          N           7.0  ...           46
# 341           57.0        NNW          N          11.0  ...           45
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# 9         1024.1       1020.7         7         1     13.3     21.7
# ..           ...          ...       ...       ...      ...      ...
# 320       1017.0       1017.6         3         1      7.1     12.2
# 327       1016.7       1017.8         7         1      8.0     14.3
# 338       1015.5       1013.2         8         4     14.5     19.3
# 339       1018.1       1013.6         8         1     11.7     19.8
# 341       1016.8       1013.3         1         1      6.9     14.6
#
#      RainToday  RISK_MM RainTomorrow
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# 9          Yes      0.0           No
# ..         ...      ...          ...
# 320        Yes      0.0           No
# 327        Yes      0.0           No
# 338        Yes      3.0          Yes
# 339        Yes      0.0           No
# 341        Yes      0.0           No
#
# [61 rows x 22 columns]

# %%
d[d['RainToday']=='Yes']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 1       14.0     26.9       3.6          4.4       9.7               ENE
# 2       13.7     23.4       3.6          5.8       3.3                NW
# 3       13.3     15.5      39.8          7.2       9.1                NW
# 4        7.6     16.1       2.8          5.6      10.6               SSE
# 9        8.4     22.8      16.2          5.4       7.7                 E
# ..       ...      ...       ...          ...       ...               ...
# 320      3.9     13.2       3.4          6.6      11.0               WNW
# 327      7.8     16.2      17.4          6.4       7.9                NW
# 338     14.4     20.7       7.6          9.4       4.9               NNW
# 339     10.3     21.3       3.0          4.2       6.7               NNW
# 341      0.3     16.0       8.2          5.4      11.8                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# 9             31.0          S        ESE           7.0  ...           32
# ..             ...        ...        ...           ...  ...          ...
# 320           65.0        WNW        WNW          26.0  ...           33
# 327           50.0         NW          N          15.0  ...           44
# 338           33.0        NNW        NNW          20.0  ...           65
# 339           43.0        ENE          N           7.0  ...           46
# 341           57.0        NNW          N          11.0  ...           45
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# 9         1024.1       1020.7         7         1     13.3     21.7
# ..           ...          ...       ...       ...      ...      ...
# 320       1017.0       1017.6         3         1      7.1     12.2
# 327       1016.7       1017.8         7         1      8.0     14.3
# 338       1015.5       1013.2         8         4     14.5     19.3
# 339       1018.1       1013.6         8         1     11.7     19.8
# 341       1016.8       1013.3         1         1      6.9     14.6
#
#      RainToday  RISK_MM RainTomorrow
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# 9          Yes      0.0           No
# ..         ...      ...          ...
# 320        Yes      0.0           No
# 327        Yes      0.0           No
# 338        Yes      3.0          Yes
# 339        Yes      0.0           No
# 341        Yes      0.0           No
#
# [61 rows x 22 columns]

# %% [markdown]
# # Operation - 15

# %%
d[d['RainToday']=='No']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 0        8.0     24.3       0.0          3.4       6.3                NW
# 5        6.2     16.9       0.0          5.8       8.2                SE
# 6        6.1     18.2       0.2          4.2       8.4                SE
# 7        8.3     17.0       0.0          5.6       4.6                 E
# 8        8.8     19.5       0.0          4.0       4.1                 S
# ..       ...      ...       ...          ...       ...               ...
# 361      9.0     30.7       0.0          7.6      12.1               NNW
# 362      7.1     28.4       0.0         11.6      12.7                 N
# 363     12.5     19.9       0.0          8.4       5.3               ESE
# 364     12.5     26.9       0.0          5.0       7.1                NW
# 365     12.3     30.2       0.0          6.0      12.6                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 5             44.0         SE          E          20.0  ...           57
# 6             43.0         SE        ESE          19.0  ...           47
# 7             41.0         SE          E          11.0  ...           57
# 8             48.0          E        ENE          19.0  ...           48
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 5         1023.8       1021.7         7         5     10.9     14.8
# 6         1024.6       1022.2         4         6     12.4     17.3
# 7         1026.2       1024.2         6         7     12.1     15.5
# 8         1026.1       1022.7         7         7     14.1     18.9
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 0           No      3.6          Yes
# 5           No      0.2           No
# 6           No      0.0           No
# 7           No      0.0           No
# 8           No     16.2          Yes
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [267 rows x 22 columns]

# %% [markdown]
# # If 'RainToday =='No' AND 'Rainfall'==0.0 AND 'RISK_MM'==0.0 Then It May be No Rain Tomorrow

# %%
d[(d['RainToday']=='No')&(d['Rainfall']==0.0)&(d['RISK_MM']==0.0)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 7        8.3     17.0       0.0          5.6       4.6                 E
# 12      10.1     27.9       0.0          7.2      13.0               WNW
# 13      12.1     30.9       0.0          6.2      12.4                NW
# 14      10.1     31.2       0.0          8.8      13.1                NW
# 15      12.4     32.1       0.0          8.4      11.1                 E
# ..       ...      ...       ...          ...       ...               ...
# 361      9.0     30.7       0.0          7.6      12.1               NNW
# 362      7.1     28.4       0.0         11.6      12.7                 N
# 363     12.5     19.9       0.0          8.4       5.3               ESE
# 364     12.5     26.9       0.0          5.0       7.1                NW
# 365     12.3     30.2       0.0          6.0      12.6                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 7             41.0         SE          E          11.0  ...           57
# 12            30.0          S         NW           6.0  ...           29
# 13            44.0        WNW          W           7.0  ...           20
# 14            41.0          S          W           6.0  ...           16
# 15            46.0         SE        WSW           7.0  ...           22
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 7         1026.2       1024.2         6         7     12.1     15.5
# 12        1022.0       1017.1         0         1     17.0     27.1
# 13        1017.3       1013.1         1         4     19.7     30.7
# 14        1018.2       1013.7         0         1     18.7     30.4
# 15        1017.9       1012.8         0         3     19.1     30.7
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 7           No      0.0           No
# 12          No      0.0           No
# 13          No      0.0           No
# 14          No      0.0           No
# 15          No      0.0           No
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [184 rows x 22 columns]

# %%
d[(d['RainToday']=='Yes')&(d['Rainfall']!=0.0)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDirection  \
# 1       14.0     26.9       3.6          4.4       9.7               ENE
# 2       13.7     23.4       3.6          5.8       3.3                NW
# 3       13.3     15.5      39.8          7.2       9.1                NW
# 4        7.6     16.1       2.8          5.6      10.6               SSE
# 9        8.4     22.8      16.2          5.4       7.7                 E
# ..       ...      ...       ...          ...       ...               ...
# 320      3.9     13.2       3.4          6.6      11.0               WNW
# 327      7.8     16.2      17.4          6.4       7.9                NW
# 338     14.4     20.7       7.6          9.4       4.9               NNW
# 339     10.3     21.3       3.0          4.2       6.7               NNW
# 341      0.3     16.0       8.2          5.4      11.8                NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# 9             31.0          S        ESE           7.0  ...           32
# ..             ...        ...        ...           ...  ...          ...
# 320           65.0        WNW        WNW          26.0  ...           33
# 327           50.0         NW          N          15.0  ...           44
# 338           33.0        NNW        NNW          20.0  ...           65
# 339           43.0        ENE          N           7.0  ...           46
# 341           57.0        NNW          N          11.0  ...           45
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# 9         1024.1       1020.7         7         1     13.3     21.7
# ..           ...          ...       ...       ...      ...      ...
# 320       1017.0       1017.6         3         1      7.1     12.2
# 327       1016.7       1017.8         7         1      8.0     14.3
# 338       1015.5       1013.2         8         4     14.5     19.3
# 339       1018.1       1013.6         8         1     11.7     19.8
# 341       1016.8       1013.3         1         1      6.9     14.6
#
#      RainToday  RISK_MM RainTomorrow
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# 9          Yes      0.0           No
# ..         ...      ...          ...
# 320        Yes      0.0           No
# 327        Yes      0.0           No
# 338        Yes      3.0          Yes
# 339        Yes      0.0           No
# 341        Yes      0.0           No
#
# [61 rows x 22 columns]

# %% [markdown]
# ### In this Weather Data Analysis we apply Following Algoriths for Weather prediction :-
#  - Decision Tree
#  - NBC
#  - SVM
#  - ARIMA

# %% [markdown]
# ### I have completed this projet with the help of online resourses and plateform.

# %% [markdown]
# - Name - Aatish Kumar Baitha
# - M.Tech(Data Science 2nd Year Student)

# %% [markdown]
# ### My Linkedin Profile -
# - www.linkedin.com/in/aatish-kumar-baitha-ba9523191

# %% [markdown]
# ### My Blog -
# - https://computersciencedatascience.blogspot.com/

# %% [markdown]
# ### Thank you!
